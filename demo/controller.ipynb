# %%
pwd
# Out:
# u'/opt/localuser/Work/pydev/spiketag/demo'

# %%
# %load_ext autoreload

# %%
# %autoreload 2

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# %gui qt

# %% [markdown]
# # load and view the probe geometry

# %%
from spiketag.probe import prb_bowtie_LL as prb

# %%
prb.show(font_size=30)
# Out:
# /opt/localuser/anaconda2/lib/python2.7/site-packages/IPython/config.py:13: ShimWarning: The `IPython.config` package has been deprecated since IPython 4.0. You should import from traitlets.config instead.
#   "You should import from traitlets.config instead.", ShimWarning)

# %% [markdown]
# ## Sort

# %%
prb.fs =25000.
prb.n_ch = 160
prb.reorder_by_chip = True
prb._nchips = 5

# %%
from spiketag.mvc.Control import controller

# %%
ctrl = controller(mua_filename='/data1/n62/new_maze/vr_08092018/mua.bin',
                  spk_filename='/data1/n62/new_maze/vr_08092018/spk.bin',
                  probe=prb, binary_radix=13,
                  playground_log='/data1/n62/new_maze/vr_08092018/process.log',
                  cutoff = [-7000, 1000],
                  session_id=14,
                  v_cutoff = 5,
                  behavior_start_time = 0
                 )
# Out:
# 2018-08-11 23:26:45,786 - spiketag - INFO - load mua data
# 2018-08-11 23:26:46,004 - spiketag - INFO - #############  load data  ###################
# 2018-08-11 23:26:46,005 - spiketag - INFO - /data1/n62/new_maze/vr_08092018/mua.bin loaded, it contains:
# 2018-08-11 23:26:46,007 - spiketag - INFO - 63983346 * 160 points (40949341440 bytes)
# 2018-08-11 23:26:46,008 - spiketag - INFO - 160 channels with sampling rate of 25000.0000
# 2018-08-11 23:26:46,010 - spiketag - INFO - 2559.334 secs (42.656 mins) of data
# 2018-08-11 23:26:46,011 - spiketag - INFO - #############################################
# 2018-08-11 23:26:48,258 - spiketag - INFO - reordered with nchips=5 and nch_perchip=32
# 2018-08-11 23:26:51,585 - spiketag - INFO - processing folder: /data1/n62/new_maze/vr_08092018/
# 2018-08-11 23:26:51,772 - spiketag - INFO - raw data have 2911724 spks
# 2018-08-11 23:26:51,774 - spiketag - INFO - ----------------success------------------
# 2018-08-11 23:26:51,776 - spiketag - INFO -

# %%
from playground.base import logger

# %%
log = logger('/data1/n62/new_maze/vr_08092018/process.log')

# %%
log.log_sessions[14]
# Out:
#                         func level                                msg  \
# 2732    jovian_process_start  INFO  ---------------------------------
# 2733                    info  INFO   child process calling self.run()
# 2734         _jovian_process  INFO         12300, [130916, 125813, 0]
# 2735         _jovian_process  INFO         12316, [130916, 125813, 0]
# 2736         _jovian_process  INFO         12333, [130916, 125813, 0]
# 2737         _jovian_process  INFO         12350, [130916, 125813, 0]
# 2738         _jovian_process  INFO         12366, [130916, 125813, 0]
# 2739         _jovian_process  INFO         12383, [130916, 125813, 0]
# 2740         _jovian_process  INFO         12400, [130916, 125813, 0]
# 2741         _jovian_process  INFO         12416, [130916, 125813, 0]
# 2742         _jovian_process  INFO         12433, [130916, 125813, 0]
# 2743         _jovian_process  INFO         12450, [130916, 125813, 0]
# 2744         _jovian_process  INFO         12466, [130916, 125813, 0]
# 2745         _jovian_process  INFO         12483, [130916, 125813, 0]
# 2746         _jovian_process  INFO         12500, [130916, 125813, 0]
# 2747         _jovian_process  INFO         12516, [130916, 125813, 0]
# 2748         _jovian_process  INFO         12533, [130916, 125813, 0]
# 2749         _jovian_process  INFO         12550, [130916, 125813, 0]
# 2750         _jovian_process  INFO         12566, [130916, 125813, 0]
# 2751         _jovian_process  INFO         12583, [130916, 125813, 0]
# 2752         _jovian_process  INFO         12600, [130916, 125813, 0]
# 2753         _jovian_process  INFO         12616, [130916, 125813, 0]
# 2754         _jovian_process  INFO         12633, [130916, 125813, 0]
# 2755         _jovian_process  INFO         12650, [130916, 125813, 0]
# 2756         _jovian_process  INFO         12666, [130916, 125813, 0]
# 2757         _jovian_process  INFO         12683, [130916, 125813, 0]
# 2758         _jovian_process  INFO         12700, [130916, 125813, 0]
# 2759         _jovian_process  INFO         12717, [130916, 125813, 0]
# 2760         _jovian_process  INFO         12733, [130916, 125813, 0]
# 2761         _jovian_process  INFO         12750, [130916, 125813, 0]
# ...                      ...   ...                                ...
# 307714       _jovian_process  INFO       5077628, [140162, 124136, 0]
# 307715       _jovian_process  INFO       5077645, [140164, 124139, 0]
# 307716       _jovian_process  INFO       5077661, [140166, 124142, 0]
# 307717       _jovian_process  INFO       5077678, [140168, 124142, 0]
# 307718       _jovian_process  INFO       5077695, [140171, 124139, 0]
# 307719       _jovian_process  INFO       5077711, [140175, 124133, 0]
# 307720       _jovian_process  INFO       5077728, [140179, 124129, 0]
# 307721       _jovian_process  INFO       5077744, [140182, 124123, 0]
# 307722       _jovian_process  INFO       5077762, [140185, 124119, 0]
# 307723       _jovian_process  INFO       5077778, [140186, 124117, 0]
# 307724       _jovian_process  INFO       5077795, [140186, 124114, 0]
# 307725       _jovian_process  INFO       5077811, [140187, 124113, 0]
# 307726       _jovian_process  INFO       5077828, [140188, 124111, 0]
# 307727       _jovian_process  INFO       5077845, [140188, 124110, 0]
# 307728       _jovian_process  INFO       5077861, [140189, 124108, 0]
# 307729       _jovian_process  INFO       5077878, [140193, 124108, 0]
# 307730       _jovian_process  INFO       5077895, [140193, 124108, 0]
# 307731       _jovian_process  INFO       5077911, [140194, 124110, 0]
# 307732       _jovian_process  INFO       5077928, [140194, 124110, 0]
# 307733       _jovian_process  INFO       5077945, [140194, 124110, 0]
# 307734       _jovian_process  INFO       5077961, [140194, 124110, 0]
# 307735       _jovian_process  INFO       5077978, [140194, 124110, 0]
# 307736       _jovian_process  INFO       5077994, [140194, 124110, 0]
# 307737       _jovian_process  INFO       5078012, [140194, 124110, 0]
# 307738       _jovian_process  INFO       5078028, [140194, 124110, 0]
# 307739       _jovian_process  INFO       5078045, [140194, 124110, 0]
# 307740       _jovian_process  INFO       5078061, [140194, 124110, 0]
# 307741       _jovian_process  INFO       5078078, [140194, 124113, 0]
# 307742       _jovian_process  INFO       5078095, [140194, 124113, 0]
# 307743  MainProcess  2018-08-09 23:12:15,427
#
# [305012 rows x 5 columns]

# %%
ctrl.sort()
# Out:
# 2018-08-11 23:27:05,897 - spiketag - INFO - extract spikes from pivital meta data
# 2018-08-11 23:27:05,901 - spiketag - INFO - mua.tospk()
# 2018-08-11 23:27:07,685 - spiketag - INFO - group 0 delete 42.7520934487%(12151.0/28422.0) spks via cutoff
# 2018-08-11 23:27:07,693 - spiketag - INFO - group 0 delete 69.0799582079%(11240.0/16271.0) spks via speed
# 2018-08-11 23:27:08,995 - spiketag - INFO - group 1 delete 33.9507336115%(12611.0/37145.0) spks via cutoff
# 2018-08-11 23:27:09,004 - spiketag - INFO - group 1 delete 64.7061221162%(15875.0/24534.0) spks via speed
# 2018-08-11 23:27:12,307 - spiketag - INFO - group 2 delete 19.275730134%(20051.0/104022.0) spks via cutoff
# 2018-08-11 23:27:12,337 - spiketag - INFO - group 2 delete 47.6200116707%(39987.0/83971.0) spks via speed
# 2018-08-11 23:27:15,414 - spiketag - INFO - group 3 delete 18.0809844162%(16986.0/93944.0) spks via cutoff
# 2018-08-11 23:27:15,439 - spiketag - INFO - group 3 delete 53.1276800333%(40886.0/76958.0) spks via speed
# 2018-08-11 23:27:16,629 - spiketag - INFO - group 4 delete 49.7591850115%(19733.0/39657.0) spks via cutoff
# 2018-08-11 23:27:16,637 - spiketag - INFO - group 4 delete 64.2892993375%(12809.0/19924.0) spks via speed
# 2018-08-11 23:27:18,778 - spiketag - INFO - group 5 delete 17.7058171846%(9749.0/55061.0) spks via cutoff
# 2018-08-11 23:27:18,795 - spiketag - INFO - group 5 delete 55.0979872881%(24966.0/45312.0) spks via speed
# 2018-08-11 23:27:22,389 - spiketag - INFO - group 6 delete 19.2024628409%(19960.0/103945.0) spks via cutoff
# 2018-08-11 23:27:22,419 - spiketag - INFO - group 6 delete 52.0985890338%(43755.0/83985.0) spks via speed
# 2018-08-11 23:27:25,685 - spiketag - INFO - group 7 delete 15.3965224767%(14522.0/94320.0) spks via cutoff
# 2018-08-11 23:27:25,707 - spiketag - INFO - group 7 delete 54.3284292839%(43353.0/79798.0) spks via speed
# 2018-08-11 23:27:27,328 - spiketag - INFO - group 8 delete 31.8590594132%(15127.0/47481.0) spks via cutoff
# 2018-08-11 23:27:27,335 - spiketag - INFO - group 8 delete 65.8372998702%(21301.0/32354.0) spks via speed
# 2018-08-11 23:27:28,533 - spiketag - INFO - group 9 delete 30.5903614458%(12695.0/41500.0) spks via cutoff
# 2018-08-11 23:27:28,538 - spiketag - INFO - group 9 delete 57.5976392987%(16591.0/28805.0) spks via speed
# 2018-08-11 23:27:35,231 - spiketag - INFO - group 10 delete 4.36305125466%(9843.0/225599.0) spks via cutoff
# 2018-08-11 23:27:35,270 - spiketag - INFO - group 10 delete 39.3917202766%(84990.0/215756.0) spks via speed
# 2018-08-11 23:27:42,656 - spiketag - INFO - group 11 delete 8.86127646935%(21480.0/242403.0) spks via cutoff
# 2018-08-11 23:27:42,698 - spiketag - INFO - group 11 delete 41.9480995641%(92673.0/220923.0) spks via speed
# 2018-08-11 23:27:44,540 - spiketag - INFO - group 12 delete 27.5456150677%(17316.0/62863.0) spks via cutoff
# 2018-08-11 23:27:44,557 - spiketag - INFO - group 12 delete 54.7676026961%(24945.0/45547.0) spks via speed
# 2018-08-11 23:27:48,043 - spiketag - INFO - group 13 delete 5.86039925882%(6705.0/114412.0) spks via cutoff
# 2018-08-11 23:27:48,078 - spiketag - INFO - group 13 delete 53.0104821414%(57096.0/107707.0) spks via speed
# 2018-08-11 23:27:49,510 - spiketag - INFO - group 14 delete 32.3113416689%(14575.0/45108.0) spks via cutoff
# 2018-08-11 23:27:49,515 - spiketag - INFO - group 14 delete 55.7495169161%(17022.0/30533.0) spks via speed
# 2018-08-11 23:27:51,196 - spiketag - INFO - group 15 delete 0.601099024336%(268.0/44585.0) spks via cutoff
# 2018-08-11 23:27:51,207 - spiketag - INFO - group 15 delete 30.9723131078%(13726.0/44317.0) spks via speed
# 2018-08-11 23:27:55,360 - spiketag - INFO - group 16 delete 0.268964811213%(289.0/107449.0) spks via cutoff
# 2018-08-11 23:27:55,396 - spiketag - INFO - group 16 delete 41.0862262038%(44028.0/107160.0) spks via speed
# 2018-08-11 23:28:01,284 - spiketag - INFO - group 17 delete 0.276883652614%(443.0/159995.0) spks via cutoff
# 2018-08-11 23:28:01,311 - spiketag - INFO - group 17 delete 42.5673134777%(67917.0/159552.0) spks via speed
# 2018-08-11 23:28:04,176 - spiketag - INFO - group 18 delete 0.487440288565%(450.0/92319.0) spks via cutoff
# 2018-08-11 23:28:04,196 - spiketag - INFO - group 18 delete 48.0793303508%(44170.0/91869.0) spks via speed
# 2018-08-11 23:28:04,810 - spiketag - INFO - group 19 delete 2.48930803816%(454.0/18238.0) spks via cutoff
# 2018-08-11 23:28:04,816 - spiketag - INFO - group 19 delete 36.032388664%(6408.0/17784.0) spks via speed
# 2018-08-11 23:28:06,045 - spiketag - INFO - group 20 delete 0.640733424505%(253.0/39486.0) spks via cutoff
# 2018-08-11 23:28:06,053 - spiketag - INFO - group 20 delete 34.2109958453%(13422.0/39233.0) spks via speed
# 2018-08-11 23:28:10,765 - spiketag - INFO - group 21 delete 0.360676374283%(510.0/141401.0) spks via cutoff
# 2018-08-11 23:28:10,806 - spiketag - INFO - group 21 delete 39.2821400941%(55345.0/140891.0) spks via speed
# 2018-08-11 23:28:16,812 - spiketag - INFO - group 22 delete 0.193480571085%(335.0/173144.0) spks via cutoff
# 2018-08-11 23:28:16,849 - spiketag - INFO - group 22 delete 41.6454004132%(71967.0/172809.0) spks via speed
# 2018-08-11 23:28:18,960 - spiketag - INFO - group 23 delete 0.826849197527%(424.0/51279.0) spks via cutoff
# 2018-08-11 23:28:18,975 - spiketag - INFO - group 23 delete 44.8274505948%(22797.0/50855.0) spks via speed
# 2018-08-11 23:28:19,764 - spiketag - INFO - group 24 delete 1.31653830102%(347.0/26357.0) spks via cutoff
# 2018-08-11 23:28:19,773 - spiketag - INFO - group 24 delete 40.0153787005%(10408.0/26010.0) spks via speed
# 2018-08-11 23:28:21,560 - spiketag - INFO - group 25 delete 0.512339893783%(246.0/48015.0) spks via cutoff
# 2018-08-11 23:28:21,577 - spiketag - INFO - group 25 delete 38.4245012456%(18355.0/47769.0) spks via speed
# 2018-08-11 23:28:32,871 - spiketag - INFO - group 26 delete 0.105897730001%(397.0/374890.0) spks via cutoff
# 2018-08-11 23:28:32,938 - spiketag - INFO - group 26 delete 38.8955200765%(145661.0/374493.0) spks via speed
# 2018-08-11 23:28:40,500 - spiketag - INFO - group 27 delete 0.308735065936%(737.0/238716.0) spks via cutoff
# 2018-08-11 23:28:40,549 - spiketag - INFO - group 27 delete 38.539535001%(91716.0/237979.0) spks via speed
# 2018-08-11 23:28:41,903 - spiketag - INFO - group 28 delete 0.776721273915%(339.0/43645.0) spks via cutoff
# 2018-08-11 23:28:41,917 - spiketag - INFO - group 28 delete 40.8950260934%(17710.0/43306.0) spks via speed
# 2018-08-11 23:28:42,099 - spiketag - INFO - group 29 delete 6.52938221999%(390.0/5973.0) spks via cutoff
# 2018-08-11 23:28:42,102 - spiketag - INFO - group 29 delete 26.0970804227%(1457.0/5583.0) spks via speed
# 2018-08-11 23:28:42,104 - spiketag - INFO - ----------------success------------------
# 2018-08-11 23:28:42,105 - spiketag - INFO -
# 2018-08-11 23:28:42,107 - spiketag - INFO - grouping spike time
# 2018-08-11 23:28:42,108 - spiketag - INFO - extrat features with weighted-pca
# 2018-08-11 23:28:42,146 - spiketag - INFO - spk._tofet(group_id=0, method=weighted-pca, ncomp=6, whiten=False)
# 2018-08-11 23:28:42,173 - spiketag - INFO - spk._tofet(group_id=1, method=weighted-pca, ncomp=6, whiten=False)
# 2018-08-11 23:28:42,306 - spiketag - INFO - spk._tofet(group_id=2, method=weighted-pca, ncomp=6, whiten=False)
# 2018-08-11 23:28:42,409 - spiketag - INFO - spk._tofet(group_id=3, method=weighted-pca, ncomp=6, whiten=False)
# 2018-08-11 23:28:42,429 - spiketag - INFO - spk._tofet(group_id=4, method=weighted-pca, ncomp=6, whiten=False)
# 2018-08-11 23:28:42,497 - spiketag - INFO - spk._tofet(group_id=5, method=weighted-pca, ncomp=6, whiten=False)
# 2018-08-11 23:28:42,602 - spiketag - INFO - spk._tofet(group_id=6, method=weighted-pca, ncomp=6, whiten=False)
# 2018-08-11 23:28:42,696 - spiketag - INFO - spk._tofet(group_id=7, method=weighted-pca, ncomp=6, whiten=False)
# 2018-08-11 23:28:42,730 - spiketag - INFO - spk._tofet(group_id=8, method=weighted-pca, ncomp=6, whiten=False)
# 2018-08-11 23:28:42,764 - spiketag - INFO - spk._tofet(group_id=9, method=weighted-pca, ncomp=6, whiten=False)
# 2018-08-11 23:28:43,130 - spiketag - INFO - spk._tofet(group_id=10, method=weighted-pca, ncomp=6, whiten=False)
# 2018-08-11 23:28:43,471 - spiketag - INFO - spk._tofet(group_id=11, method=weighted-pca, ncomp=6, whiten=False)
# 2018-08-11 23:28:43,523 - spiketag - INFO - spk._tofet(group_id=12, method=weighted-pca, ncomp=6, whiten=False)
# 2018-08-11 23:28:43,644 - spiketag - INFO - spk._tofet(group_id=13, method=weighted-pca, ncomp=6, whiten=False)
# 2018-08-11 23:28:43,680 - spiketag - INFO - spk._tofet(group_id=14, method=weighted-pca, ncomp=6, whiten=False)
# 2018-08-11 23:28:43,767 - spiketag - INFO - spk._tofet(group_id=15, method=weighted-pca, ncomp=6, whiten=False)
# 2018-08-11 23:28:43,929 - spiketag - INFO - spk._tofet(group_id=16, method=weighted-pca, ncomp=6, whiten=False)
# 2018-08-11 23:28:44,165 - spiketag - INFO - spk._tofet(group_id=17, method=weighted-pca, ncomp=6, whiten=False)
# 2018-08-11 23:28:44,284 - spiketag - INFO - spk._tofet(group_id=18, method=weighted-pca, ncomp=6, whiten=False)
# 2018-08-11 23:28:44,318 - spiketag - INFO - spk._tofet(group_id=19, method=weighted-pca, ncomp=6, whiten=False)
# 2018-08-11 23:28:44,383 - spiketag - INFO - spk._tofet(group_id=20, method=weighted-pca, ncomp=6, whiten=False)
# 2018-08-11 23:28:44,617 - spiketag - INFO - spk._tofet(group_id=21, method=weighted-pca, ncomp=6, whiten=False)
# 2018-08-11 23:28:44,887 - spiketag - INFO - spk._tofet(group_id=22, method=weighted-pca, ncomp=6, whiten=False)
# 2018-08-11 23:28:44,955 - spiketag - INFO - spk._tofet(group_id=23, method=weighted-pca, ncomp=6, whiten=False)
# 2018-08-11 23:28:44,995 - spiketag - INFO - spk._tofet(group_id=24, method=weighted-pca, ncomp=6, whiten=False)
# 2018-08-11 23:28:45,064 - spiketag - INFO - spk._tofet(group_id=25, method=weighted-pca, ncomp=6, whiten=False)
# 2018-08-11 23:28:45,630 - spiketag - INFO - spk._tofet(group_id=26, method=weighted-pca, ncomp=6, whiten=False)
# 2018-08-11 23:28:45,988 - spiketag - INFO - spk._tofet(group_id=27, method=weighted-pca, ncomp=6, whiten=False)
# 2018-08-11 23:28:46,042 - spiketag - INFO - spk._tofet(group_id=28, method=weighted-pca, ncomp=6, whiten=False)
# 2018-08-11 23:28:46,055 - spiketag - INFO - spk._tofet(group_id=29, method=weighted-pca, ncomp=6, whiten=False)
# 2018-08-11 23:28:46,056 - spiketag - INFO - ----------------success------------------
# 2018-08-11 23:28:46,058 - spiketag - INFO -
# 2018-08-11 23:28:46,059 - spiketag - INFO - clustering with hdbscan
# 2018-08-11 23:28:46,060 - spiketag - INFO - clustering start with 24 cpus
# 2018-08-11 23:30:37,707 - spiketag - INFO - clustering finished, used 111.64516592 sec
# 2018-08-11 23:30:37,711 - spiketag - INFO - Model.spktag is generated, nspk:1499412

# %%
ctrl.show()
# Out:
# (6, array([ 0, 31, 34, 47]))
# WARNING: Traceback (most recent call last):
#   File "/opt/localuser/anaconda2/lib/python2.7/runpy.py", line 174, in _run_module_as_main
#     "__main__", fname, loader, pkg_name)
#   File "/opt/localuser/anaconda2/lib/python2.7/runpy.py", line 72, in _run_code
#     exec code in run_globals
#   File "/opt/localuser/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/opt/localuser/anaconda2/lib/python2.7/site-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/opt/localuser/anaconda2/lib/python2.7/site-packages/ipykernel/kernelapp.py", line 478, in start
#     self.io_loop.start()
#   File "/opt/localuser/anaconda2/lib/python2.7/site-packages/zmq/eventloop/ioloop.py", line 177, in start
#     super(ZMQIOLoop, self).start()
#   File "/opt/localuser/anaconda2/lib/python2.7/site-packages/tornado/ioloop.py", line 832, in start
#     self._run_callback(self._callbacks.popleft())
#   File "/opt/localuser/anaconda2/lib/python2.7/site-packages/tornado/ioloop.py", line 605, in _run_callback
#     ret = callback()
#   File "/opt/localuser/anaconda2/lib/python2.7/site-packages/tornado/stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/opt/localuser/anaconda2/lib/python2.7/site-packages/ipykernel/kernelbase.py", line 263, in enter_eventloop
#     self.eventloop(self)
#   File "/opt/localuser/anaconda2/lib/python2.7/site-packages/ipykernel/eventloops.py", line 123, in loop_qt5
#     return loop_qt4(kernel)
#   File "/opt/localuser/anaconda2/lib/python2.7/site-packages/ipykernel/eventloops.py", line 111, in loop_qt4
#     _loop_qt(kernel.app)
#   File "/opt/localuser/anaconda2/lib/python2.7/site-packages/ipykernel/eventloops.py", line 95, in _loop_qt
#     app.exec_()
#   File "/opt/localuser/Work/pydev/vispy/vispy/app/backends/_qt.py", line 413, in keyPressEvent
#     self._keyEvent(self._vispy_canvas.events.key_press, ev)
#   File "/opt/localuser/Work/pydev/vispy/vispy/app/backends/_qt.py", line 428, in _keyEvent
#     func(native=ev, key=key, text=text_type(ev.text()), modifiers=mod)
#   File "/opt/localuser/Work/pydev/vispy/vispy/util/event.py", line 455, in __call__
#     self._invoke_callback(cb, event)
#   File "/opt/localuser/Work/pydev/vispy/vispy/util/event.py", line 475, in _invoke_callback
#     self, cb_event=(cb, event))
#   << caught exception here: >>
#   File "/opt/localuser/Work/pydev/vispy/vispy/util/event.py", line 471, in _invoke_callback
#     cb(event)
#   File "/opt/localuser/Work/pydev/spiketag/spiketag/view/scatter_2d_view.py", line 136, in on_key_press
#     self.clip.emit('clip', thres=self.amp)
# AttributeError: 'amplitude_view' object has no attribute 'amp'
# ERROR: Invoking <bound method amplitude_view.on_key_press of <amplitude_view (PyQt5) at 0x7fd79e8b3ed0>> for KeyEvent
# delete (43,) spikes
# delete (99,) spikes
# delete (13,) spikes
# 2018-08-11 23:33:14,006 - spiketag - DEBUG - ctree view expand clustier 40078 here
# 2018-08-11 23:33:16,416 - spiketag - DEBUG - ctree view expand clustier 40080 here
# 2018-08-11 23:33:17,863 - spiketag - DEBUG - ctree view expand clustier 40082 here
# 2018-08-11 23:33:19,106 - spiketag - DEBUG - ctree view expand clustier 40085 here

# %%
current_time = ctrl.model.mua.spk_times[ctrl.current_group][ctrl.view.spkview.selected_spk]/ctrl.model.mua.fs
ctrl.model.mua.show(prb.chs, time=current_time, span=0.5)

# %%
current_time
# Out:
# array([1574.05072])

# %%
ctrl.get_fields()

# %%
ctrl.plot_fields()

# %%
# !mkdir /data1/n62/new_maze/vr_08092018/spiketag

# %%
ctrl.save('/data1/n62/new_maze/vr_08092018/spiketag/place_cells')

# %% [markdown]
# ## Sort based on previous saved spiketag

# %%
prb.fs =25000.
prb.n_ch = 160
prb.reorder_by_chip = True
prb._nchips = 5

# %%
from spiketag.mvc.Control import controller

# %%
ctrl = controller('/data1/spiketag_demo/mua.bin', 
                  '/data1/spiketag_demo/spk.bin', 
                  prb, spktag_filename='/data1/spiketag_demo/spiketag/test')
# Out:
# 2018-07-17 22:01:31,397 - spiketag - INFO - load spktag file
# 2018-07-17 22:01:32,613 - spiketag - INFO - load mua data for wave view
# 2018-07-17 22:01:32,616 - spiketag - INFO - #############  load data  ###################
# 2018-07-17 22:01:32,618 - spiketag - INFO - /data1/spiketag_demo/mua.bin loaded, it contains:
# 2018-07-17 22:01:32,620 - spiketag - INFO - 17059414 * 160 points (10918024960 bytes)
# 2018-07-17 22:01:32,622 - spiketag - INFO - 160 channels with sampling rate of 25000.0000
# 2018-07-17 22:01:32,624 - spiketag - INFO - 682.377 secs (11.373 mins) of data
# 2018-07-17 22:01:32,625 - spiketag - INFO - #############################################
# 2018-07-17 22:01:33,905 - spiketag - INFO - reordered with nchips=5 and nch_perchip=32
# 2018-07-17 22:01:37,273 - spiketag - INFO - processing folder: /data1/spiketag_demo/
# 2018-07-17 22:01:37,314 - spiketag - INFO - raw data have 655193 spks
# 2018-07-17 22:01:37,316 - spiketag - INFO - ----------------success------------------
# 2018-07-17 22:01:37,317 - spiketag - INFO -
# 2018-07-17 22:01:37,320 - spiketag - INFO - Model.spktag is generated, nspk:508026

# %%
ctrl.show()
# Out:
# WARNING: Traceback (most recent call last):
#   File "/opt/localuser/anaconda2/lib/python2.7/runpy.py", line 174, in _run_module_as_main
#     "__main__", fname, loader, pkg_name)
#   File "/opt/localuser/anaconda2/lib/python2.7/runpy.py", line 72, in _run_code
#     exec code in run_globals
#   File "/opt/localuser/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/opt/localuser/anaconda2/lib/python2.7/site-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/opt/localuser/anaconda2/lib/python2.7/site-packages/ipykernel/kernelapp.py", line 478, in start
#     self.io_loop.start()
#   File "/opt/localuser/anaconda2/lib/python2.7/site-packages/zmq/eventloop/ioloop.py", line 177, in start
#     super(ZMQIOLoop, self).start()
#   File "/opt/localuser/anaconda2/lib/python2.7/site-packages/tornado/ioloop.py", line 832, in start
#     self._run_callback(self._callbacks.popleft())
#   File "/opt/localuser/anaconda2/lib/python2.7/site-packages/tornado/ioloop.py", line 605, in _run_callback
#     ret = callback()
#   File "/opt/localuser/anaconda2/lib/python2.7/site-packages/tornado/stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/opt/localuser/anaconda2/lib/python2.7/site-packages/ipykernel/kernelbase.py", line 263, in enter_eventloop
#     self.eventloop(self)
#   File "/opt/localuser/anaconda2/lib/python2.7/site-packages/ipykernel/eventloops.py", line 123, in loop_qt5
#     return loop_qt4(kernel)
#   File "/opt/localuser/anaconda2/lib/python2.7/site-packages/ipykernel/eventloops.py", line 111, in loop_qt4
#     _loop_qt(kernel.app)
#   File "/opt/localuser/anaconda2/lib/python2.7/site-packages/ipykernel/eventloops.py", line 95, in _loop_qt
#     app.exec_()
#   File "/opt/localuser/Work/pydev/vispy/vispy/app/backends/_qt.py", line 387, in mouseMoveEvent
#     modifiers=self._modifiers(ev),
#   File "/opt/localuser/Work/pydev/vispy/vispy/app/base.py", line 202, in _vispy_mouse_move
#     ev = self._vispy_canvas.events.mouse_move(**kwargs)
#   File "/opt/localuser/Work/pydev/vispy/vispy/util/event.py", line 455, in __call__
#     self._invoke_callback(cb, event)
#   File "/opt/localuser/Work/pydev/vispy/vispy/util/event.py", line 475, in _invoke_callback
#     self, cb_event=(cb, event))
#   << caught exception here: >>
#   File "/opt/localuser/Work/pydev/vispy/vispy/util/event.py", line 471, in _invoke_callback
#     cb(event)
#   File "/opt/localuser/Work/pydev/spiketag/spiketag/view/ctree_view.py", line 76, in on_mouse_move
#     self._select(current_cluster)
#   File "/opt/localuser/Work/pydev/spiketag/spiketag/view/ctree_view.py", line 178, in _select
#     self._clu.select(global_idx)
#   File "/opt/localuser/Work/pydev/spiketag/spiketag/base/CLU.py", line 155, in select
#     self.emit('select', action='select', caller=caller)
#   File "/opt/localuser/Work/pydev/spiketag/spiketag/utils/utils.py", line 160, in emit
#     res.append(callback(*args, **kwargs))
#   File "/opt/localuser/Work/pydev/spiketag/spiketag/view/spike_view.py", line 114, in on_select
#     self._selected = self.clu.global2local(self.clu.selectlist)
#   File "/opt/localuser/Work/pydev/spiketag/spiketag/base/CLU.py", line 78, in global2local
#     clus_nos = np.unique(self.membership[global_idx])
# IndexError: index 24901 is out of bounds for axis 1 with size 24728
# ERROR: Invoking <bound method ctree_view.on_mouse_move of <ctree_view (PyQt5) at 0x7f3ba054aad0>> for MouseEvent
# WARNING: Traceback (most recent call last):
#   File "/opt/localuser/anaconda2/lib/python2.7/runpy.py", line 174, in _run_module_as_main
#     "__main__", fname, loader, pkg_name)
#   File "/opt/localuser/anaconda2/lib/python2.7/runpy.py", line 72, in _run_code
#     exec code in run_globals
#   File "/opt/localuser/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/opt/localuser/anaconda2/lib/python2.7/site-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/opt/localuser/anaconda2/lib/python2.7/site-packages/ipykernel/kernelapp.py", line 478, in start
#     self.io_loop.start()
#   File "/opt/localuser/anaconda2/lib/python2.7/site-packages/zmq/eventloop/ioloop.py", line 177, in start
#     super(ZMQIOLoop, self).start()
#   File "/opt/localuser/anaconda2/lib/python2.7/site-packages/tornado/ioloop.py", line 832, in start
#     self._run_callback(self._callbacks.popleft())
#   File "/opt/localuser/anaconda2/lib/python2.7/site-packages/tornado/ioloop.py", line 605, in _run_callback
#     ret = callback()
#   File "/opt/localuser/anaconda2/lib/python2.7/site-packages/tornado/stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/opt/localuser/anaconda2/lib/python2.7/site-packages/ipykernel/kernelbase.py", line 263, in enter_eventloop
#     self.eventloop(self)
#   File "/opt/localuser/anaconda2/lib/python2.7/site-packages/ipykernel/eventloops.py", line 123, in loop_qt5
#     return loop_qt4(kernel)
#   File "/opt/localuser/anaconda2/lib/python2.7/site-packages/ipykernel/eventloops.py", line 111, in loop_qt4
#     _loop_qt(kernel.app)
#   File "/opt/localuser/anaconda2/lib/python2.7/site-packages/ipykernel/eventloops.py", line 95, in _loop_qt
#     app.exec_()
#   File "/opt/localuser/Work/pydev/vispy/vispy/app/backends/_qt.py", line 387, in mouseMoveEvent
#     modifiers=self._modifiers(ev),
#   File "/opt/localuser/Work/pydev/vispy/vispy/app/base.py", line 202, in _vispy_mouse_move
#     ev = self._vispy_canvas.events.mouse_move(**kwargs)
#   File "/opt/localuser/Work/pydev/vispy/vispy/util/event.py", line 455, in __call__
#     self._invoke_callback(cb, event)
#   File "/opt/localuser/Work/pydev/vispy/vispy/util/event.py", line 475, in _invoke_callback
#     self, cb_event=(cb, event))
#   << caught exception here: >>
#   File "/opt/localuser/Work/pydev/vispy/vispy/util/event.py", line 471, in _invoke_callback
#     cb(event)
#   File "/opt/localuser/Work/pydev/spiketag/spiketag/view/ctree_view.py", line 76, in on_mouse_move
#     self._select(current_cluster)
#   File "/opt/localuser/Work/pydev/spiketag/spiketag/view/ctree_view.py", line 178, in _select
#     self._clu.select(global_idx)
#   File "/opt/localuser/Work/pydev/spiketag/spiketag/base/CLU.py", line 155, in select
#     self.emit('select', action='select', caller=caller)
#   File "/opt/localuser/Work/pydev/spiketag/spiketag/utils/utils.py", line 160, in emit
#     res.append(callback(*args, **kwargs))
#   File "/opt/localuser/Work/pydev/spiketag/spiketag/view/spike_view.py", line 114, in on_select
#     self._selected = self.clu.global2local(self.clu.selectlist)
#   File "/opt/localuser/Work/pydev/spiketag/spiketag/base/CLU.py", line 78, in global2local
#     clus_nos = np.unique(self.membership[global_idx])
# IndexError: index 24901 is out of bounds for axis 1 with size 24728
# ERROR: Invoking <bound method ctree_view.on_mouse_move of <ctree_view (PyQt5) at 0x7f3ba054aad0>> for MouseEvent
# WARNING: Traceback (most recent call last):
#   File "/opt/localuser/anaconda2/lib/python2.7/runpy.py", line 174, in _run_module_as_main
#     "__main__", fname, loader, pkg_name)
#   File "/opt/localuser/anaconda2/lib/python2.7/runpy.py", line 72, in _run_code
#     exec code in run_globals
#   File "/opt/localuser/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/opt/localuser/anaconda2/lib/python2.7/site-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/opt/localuser/anaconda2/lib/python2.7/site-packages/ipykernel/kernelapp.py", line 478, in start
#     self.io_loop.start()
#   File "/opt/localuser/anaconda2/lib/python2.7/site-packages/zmq/eventloop/ioloop.py", line 177, in start
#     super(ZMQIOLoop, self).start()
#   File "/opt/localuser/anaconda2/lib/python2.7/site-packages/tornado/ioloop.py", line 832, in start
#     self._run_callback(self._callbacks.popleft())
#   File "/opt/localuser/anaconda2/lib/python2.7/site-packages/tornado/ioloop.py", line 605, in _run_callback
#     ret = callback()
#   File "/opt/localuser/anaconda2/lib/python2.7/site-packages/tornado/stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/opt/localuser/anaconda2/lib/python2.7/site-packages/ipykernel/kernelbase.py", line 263, in enter_eventloop
#     self.eventloop(self)
#   File "/opt/localuser/anaconda2/lib/python2.7/site-packages/ipykernel/eventloops.py", line 123, in loop_qt5
#     return loop_qt4(kernel)
#   File "/opt/localuser/anaconda2/lib/python2.7/site-packages/ipykernel/eventloops.py", line 111, in loop_qt4
#     _loop_qt(kernel.app)
#   File "/opt/localuser/anaconda2/lib/python2.7/site-packages/ipykernel/eventloops.py", line 95, in _loop_qt
#     app.exec_()
#   File "/opt/localuser/Work/pydev/vispy/vispy/app/backends/_qt.py", line 387, in mouseMoveEvent
#     modifiers=self._modifiers(ev),
#   File "/opt/localuser/Work/pydev/vispy/vispy/app/base.py", line 202, in _vispy_mouse_move
#     ev = self._vispy_canvas.events.mouse_move(**kwargs)
#   File "/opt/localuser/Work/pydev/vispy/vispy/util/event.py", line 455, in __call__
#     self._invoke_callback(cb, event)
#   File "/opt/localuser/Work/pydev/vispy/vispy/util/event.py", line 475, in _invoke_callback
#     self, cb_event=(cb, event))
#   << caught exception here: >>
#   File "/opt/localuser/Work/pydev/vispy/vispy/util/event.py", line 471, in _invoke_callback
#     cb(event)
#   File "/opt/localuser/Work/pydev/spiketag/spiketag/view/ctree_view.py", line 76, in on_mouse_move
#     self._select(current_cluster)
#   File "/opt/localuser/Work/pydev/spiketag/spiketag/view/ctree_view.py", line 178, in _select
#     self._clu.select(global_idx)
#   File "/opt/localuser/Work/pydev/spiketag/spiketag/base/CLU.py", line 155, in select
#     self.emit('select', action='select', caller=caller)
#   File "/opt/localuser/Work/pydev/spiketag/spiketag/utils/utils.py", line 160, in emit
#     res.append(callback(*args, **kwargs))
#   File "/opt/localuser/Work/pydev/spiketag/spiketag/view/spike_view.py", line 114, in on_select
#     self._selected = self.clu.global2local(self.clu.selectlist)
#   File "/opt/localuser/Work/pydev/spiketag/spiketag/base/CLU.py", line 78, in global2local
#     clus_nos = np.unique(self.membership[global_idx])
# IndexError: index 24901 is out of bounds for axis 1 with size 24728
# ERROR: Invoking <bound method ctree_view.on_mouse_move of <ctree_view (PyQt5) at 0x7f3ba054aad0>> for MouseEvent
# WARNING: Traceback (most recent call last):
#   File "/opt/localuser/anaconda2/lib/python2.7/runpy.py", line 174, in _run_module_as_main
#     "__main__", fname, loader, pkg_name)
#   File "/opt/localuser/anaconda2/lib/python2.7/runpy.py", line 72, in _run_code
#     exec code in run_globals
#   File "/opt/localuser/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/opt/localuser/anaconda2/lib/python2.7/site-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/opt/localuser/anaconda2/lib/python2.7/site-packages/ipykernel/kernelapp.py", line 478, in start
#     self.io_loop.start()
#   File "/opt/localuser/anaconda2/lib/python2.7/site-packages/zmq/eventloop/ioloop.py", line 177, in start
#     super(ZMQIOLoop, self).start()
#   File "/opt/localuser/anaconda2/lib/python2.7/site-packages/tornado/ioloop.py", line 832, in start
#     self._run_callback(self._callbacks.popleft())
#   File "/opt/localuser/anaconda2/lib/python2.7/site-packages/tornado/ioloop.py", line 605, in _run_callback
#     ret = callback()
#   File "/opt/localuser/anaconda2/lib/python2.7/site-packages/tornado/stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/opt/localuser/anaconda2/lib/python2.7/site-packages/ipykernel/kernelbase.py", line 263, in enter_eventloop
#     self.eventloop(self)
#   File "/opt/localuser/anaconda2/lib/python2.7/site-packages/ipykernel/eventloops.py", line 123, in loop_qt5
#     return loop_qt4(kernel)
#   File "/opt/localuser/anaconda2/lib/python2.7/site-packages/ipykernel/eventloops.py", line 111, in loop_qt4
#     _loop_qt(kernel.app)
#   File "/opt/localuser/anaconda2/lib/python2.7/site-packages/ipykernel/eventloops.py", line 95, in _loop_qt
#     app.exec_()
#   File "/opt/localuser/Work/pydev/vispy/vispy/app/backends/_qt.py", line 387, in mouseMoveEvent
#     modifiers=self._modifiers(ev),
#   File "/opt/localuser/Work/pydev/vispy/vispy/app/base.py", line 202, in _vispy_mouse_move
#     ev = self._vispy_canvas.events.mouse_move(**kwargs)
#   File "/opt/localuser/Work/pydev/vispy/vispy/util/event.py", line 455, in __call__
#     self._invoke_callback(cb, event)
#   File "/opt/localuser/Work/pydev/vispy/vispy/util/event.py", line 475, in _invoke_callback
#     self, cb_event=(cb, event))
#   << caught exception here: >>
#   File "/opt/localuser/Work/pydev/vispy/vispy/util/event.py", line 471, in _invoke_callback
#     cb(event)
#   File "/opt/localuser/Work/pydev/spiketag/spiketag/view/ctree_view.py", line 76, in on_mouse_move
#     self._select(current_cluster)
#   File "/opt/localuser/Work/pydev/spiketag/spiketag/view/ctree_view.py", line 178, in _select
#     self._clu.select(global_idx)
#   File "/opt/localuser/Work/pydev/spiketag/spiketag/base/CLU.py", line 155, in select
#     self.emit('select', action='select', caller=caller)
#   File "/opt/localuser/Work/pydev/spiketag/spiketag/utils/utils.py", line 160, in emit
#     res.append(callback(*args, **kwargs))
#   File "/opt/localuser/Work/pydev/spiketag/spiketag/view/spike_view.py", line 114, in on_select
#     self._selected = self.clu.global2local(self.clu.selectlist)
#   File "/opt/localuser/Work/pydev/spiketag/spiketag/base/CLU.py", line 78, in global2local
#     clus_nos = np.unique(self.membership[global_idx])
# IndexError: index 24901 is out of bounds for axis 1 with size 24728
# ERROR: Invoking <bound method ctree_view.on_mouse_move of <ctree_view (PyQt5) at 0x7f3ba054aad0>> for MouseEvent
# WARNING: Traceback (most recent call last):
#   File "/opt/localuser/anaconda2/lib/python2.7/runpy.py", line 174, in _run_module_as_main
#     "__main__", fname, loader, pkg_name)
#   File "/opt/localuser/anaconda2/lib/python2.7/runpy.py", line 72, in _run_code
#     exec code in run_globals
#   File "/opt/localuser/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/opt/localuser/anaconda2/lib/python2.7/site-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/opt/localuser/anaconda2/lib/python2.7/site-packages/ipykernel/kernelapp.py", line 478, in start
#     self.io_loop.start()
#   File "/opt/localuser/anaconda2/lib/python2.7/site-packages/zmq/eventloop/ioloop.py", line 177, in start
#     super(ZMQIOLoop, self).start()
#   File "/opt/localuser/anaconda2/lib/python2.7/site-packages/tornado/ioloop.py", line 832, in start
#     self._run_callback(self._callbacks.popleft())
#   File "/opt/localuser/anaconda2/lib/python2.7/site-packages/tornado/ioloop.py", line 605, in _run_callback
#     ret = callback()
#   File "/opt/localuser/anaconda2/lib/python2.7/site-packages/tornado/stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/opt/localuser/anaconda2/lib/python2.7/site-packages/ipykernel/kernelbase.py", line 263, in enter_eventloop
#     self.eventloop(self)
#   File "/opt/localuser/anaconda2/lib/python2.7/site-packages/ipykernel/eventloops.py", line 123, in loop_qt5
#     return loop_qt4(kernel)
#   File "/opt/localuser/anaconda2/lib/python2.7/site-packages/ipykernel/eventloops.py", line 111, in loop_qt4
#     _loop_qt(kernel.app)
#   File "/opt/localuser/anaconda2/lib/python2.7/site-packages/ipykernel/eventloops.py", line 95, in _loop_qt
#     app.exec_()
#   File "/opt/localuser/Work/pydev/vispy/vispy/app/backends/_qt.py", line 387, in mouseMoveEvent
#     modifiers=self._modifiers(ev),
#   File "/opt/localuser/Work/pydev/vispy/vispy/app/base.py", line 202, in _vispy_mouse_move
#     ev = self._vispy_canvas.events.mouse_move(**kwargs)
#   File "/opt/localuser/Work/pydev/vispy/vispy/util/event.py", line 455, in __call__
#     self._invoke_callback(cb, event)
#   File "/opt/localuser/Work/pydev/vispy/vispy/util/event.py", line 475, in _invoke_callback
#     self, cb_event=(cb, event))
#   << caught exception here: >>
#   File "/opt/localuser/Work/pydev/vispy/vispy/util/event.py", line 471, in _invoke_callback
#     cb(event)
#   File "/opt/localuser/Work/pydev/spiketag/spiketag/view/ctree_view.py", line 76, in on_mouse_move
#     self._select(current_cluster)
#   File "/opt/localuser/Work/pydev/spiketag/spiketag/view/ctree_view.py", line 178, in _select
#     self._clu.select(global_idx)
#   File "/opt/localuser/Work/pydev/spiketag/spiketag/base/CLU.py", line 155, in select
#     self.emit('select', action='select', caller=caller)
#   File "/opt/localuser/Work/pydev/spiketag/spiketag/utils/utils.py", line 160, in emit
#     res.append(callback(*args, **kwargs))
#   File "/opt/localuser/Work/pydev/spiketag/spiketag/view/spike_view.py", line 114, in on_select
#     self._selected = self.clu.global2local(self.clu.selectlist)
#   File "/opt/localuser/Work/pydev/spiketag/spiketag/base/CLU.py", line 78, in global2local
#     clus_nos = np.unique(self.membership[global_idx])
# IndexError: index 24901 is out of bounds for axis 1 with size 24728
# ERROR: Invoking <bound method ctree_view.on_mouse_move of <ctree_view (PyQt5) at 0x7f3ba054aad0>> for MouseEvent
# WARNING: Traceback (most recent call last):
#   File "/opt/localuser/anaconda2/lib/python2.7/runpy.py", line 174, in _run_module_as_main
#     "__main__", fname, loader, pkg_name)
#   File "/opt/localuser/anaconda2/lib/python2.7/runpy.py", line 72, in _run_code
#     exec code in run_globals
#   File "/opt/localuser/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/opt/localuser/anaconda2/lib/python2.7/site-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/opt/localuser/anaconda2/lib/python2.7/site-packages/ipykernel/kernelapp.py", line 478, in start
#     self.io_loop.start()
#   File "/opt/localuser/anaconda2/lib/python2.7/site-packages/zmq/eventloop/ioloop.py", line 177, in start
#     super(ZMQIOLoop, self).start()
#   File "/opt/localuser/anaconda2/lib/python2.7/site-packages/tornado/ioloop.py", line 832, in start
#     self._run_callback(self._callbacks.popleft())
#   File "/opt/localuser/anaconda2/lib/python2.7/site-packages/tornado/ioloop.py", line 605, in _run_callback
#     ret = callback()
#   File "/opt/localuser/anaconda2/lib/python2.7/site-packages/tornado/stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/opt/localuser/anaconda2/lib/python2.7/site-packages/ipykernel/kernelbase.py", line 263, in enter_eventloop
#     self.eventloop(self)
#   File "/opt/localuser/anaconda2/lib/python2.7/site-packages/ipykernel/eventloops.py", line 123, in loop_qt5
#     return loop_qt4(kernel)
#   File "/opt/localuser/anaconda2/lib/python2.7/site-packages/ipykernel/eventloops.py", line 111, in loop_qt4
#     _loop_qt(kernel.app)
#   File "/opt/localuser/anaconda2/lib/python2.7/site-packages/ipykernel/eventloops.py", line 95, in _loop_qt
#     app.exec_()
#   File "/opt/localuser/Work/pydev/vispy/vispy/app/backends/_qt.py", line 387, in mouseMoveEvent
#     modifiers=self._modifiers(ev),
#   File "/opt/localuser/Work/pydev/vispy/vispy/app/base.py", line 202, in _vispy_mouse_move
#     ev = self._vispy_canvas.events.mouse_move(**kwargs)
#   File "/opt/localuser/Work/pydev/vispy/vispy/util/event.py", line 455, in __call__
#     self._invoke_callback(cb, event)
#   File "/opt/localuser/Work/pydev/vispy/vispy/util/event.py", line 475, in _invoke_callback
#     self, cb_event=(cb, event))
#   << caught exception here: >>
#   File "/opt/localuser/Work/pydev/vispy/vispy/util/event.py", line 471, in _invoke_callback
#     cb(event)
#   File "/opt/localuser/Work/pydev/spiketag/spiketag/view/ctree_view.py", line 76, in on_mouse_move
#     self._select(current_cluster)
#   File "/opt/localuser/Work/pydev/spiketag/spiketag/view/ctree_view.py", line 178, in _select
#     self._clu.select(global_idx)
#   File "/opt/localuser/Work/pydev/spiketag/spiketag/base/CLU.py", line 155, in select
#     self.emit('select', action='select', caller=caller)
#   File "/opt/localuser/Work/pydev/spiketag/spiketag/utils/utils.py", line 160, in emit
#     res.append(callback(*args, **kwargs))
#   File "/opt/localuser/Work/pydev/spiketag/spiketag/view/spike_view.py", line 114, in on_select
#     self._selected = self.clu.global2local(self.clu.selectlist)
#   File "/opt/localuser/Work/pydev/spiketag/spiketag/base/CLU.py", line 78, in global2local
#     clus_nos = np.unique(self.membership[global_idx])
# IndexError: index 24901 is out of bounds for axis 1 with size 24728
# ERROR: Invoking <bound method ctree_view.on_mouse_move of <ctree_view (PyQt5) at 0x7f3ba054aad0>> for MouseEvent
# WARNING: Traceback (most recent call last):
#   File "/opt/localuser/anaconda2/lib/python2.7/runpy.py", line 174, in _run_module_as_main
#     "__main__", fname, loader, pkg_name)
#   File "/opt/localuser/anaconda2/lib/python2.7/runpy.py", line 72, in _run_code
#     exec code in run_globals
#   File "/opt/localuser/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/opt/localuser/anaconda2/lib/python2.7/site-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/opt/localuser/anaconda2/lib/python2.7/site-packages/ipykernel/kernelapp.py", line 478, in start
#     self.io_loop.start()
#   File "/opt/localuser/anaconda2/lib/python2.7/site-packages/zmq/eventloop/ioloop.py", line 177, in start
#     super(ZMQIOLoop, self).start()
#   File "/opt/localuser/anaconda2/lib/python2.7/site-packages/tornado/ioloop.py", line 832, in start
#     self._run_callback(self._callbacks.popleft())
#   File "/opt/localuser/anaconda2/lib/python2.7/site-packages/tornado/ioloop.py", line 605, in _run_callback
#     ret = callback()
#   File "/opt/localuser/anaconda2/lib/python2.7/site-packages/tornado/stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/opt/localuser/anaconda2/lib/python2.7/site-packages/ipykernel/kernelbase.py", line 263, in enter_eventloop
#     self.eventloop(self)
#   File "/opt/localuser/anaconda2/lib/python2.7/site-packages/ipykernel/eventloops.py", line 123, in loop_qt5
#     return loop_qt4(kernel)
#   File "/opt/localuser/anaconda2/lib/python2.7/site-packages/ipykernel/eventloops.py", line 111, in loop_qt4
#     _loop_qt(kernel.app)
#   File "/opt/localuser/anaconda2/lib/python2.7/site-packages/ipykernel/eventloops.py", line 95, in _loop_qt
#     app.exec_()
#   File "/opt/localuser/Work/pydev/vispy/vispy/app/backends/_qt.py", line 387, in mouseMoveEvent
#     modifiers=self._modifiers(ev),
#   File "/opt/localuser/Work/pydev/vispy/vispy/app/base.py", line 202, in _vispy_mouse_move
#     ev = self._vispy_canvas.events.mouse_move(**kwargs)
#   File "/opt/localuser/Work/pydev/vispy/vispy/util/event.py", line 455, in __call__
#     self._invoke_callback(cb, event)
#   File "/opt/localuser/Work/pydev/vispy/vispy/util/event.py", line 475, in _invoke_callback
#     self, cb_event=(cb, event))
#   << caught exception here: >>
#   File "/opt/localuser/Work/pydev/vispy/vispy/util/event.py", line 471, in _invoke_callback
#     cb(event)
#   File "/opt/localuser/Work/pydev/spiketag/spiketag/view/ctree_view.py", line 76, in on_mouse_move
#     self._select(current_cluster)
#   File "/opt/localuser/Work/pydev/spiketag/spiketag/view/ctree_view.py", line 178, in _select
#     self._clu.select(global_idx)
#   File "/opt/localuser/Work/pydev/spiketag/spiketag/base/CLU.py", line 155, in select
#     self.emit('select', action='select', caller=caller)
#   File "/opt/localuser/Work/pydev/spiketag/spiketag/utils/utils.py", line 160, in emit
#     res.append(callback(*args, **kwargs))
#   File "/opt/localuser/Work/pydev/spiketag/spiketag/view/spike_view.py", line 114, in on_select
#     self._selected = self.clu.global2local(self.clu.selectlist)
#   File "/opt/localuser/Work/pydev/spiketag/spiketag/base/CLU.py", line 78, in global2local
#     clus_nos = np.unique(self.membership[global_idx])
# IndexError: index 24901 is out of bounds for axis 1 with size 24728
# ERROR: Invoking <bound method ctree_view.on_mouse_move of <ctree_view (PyQt5) at 0x7f3ba054aad0>> for MouseEvent
# WARNING: Traceback (most recent call last):
#   File "/opt/localuser/anaconda2/lib/python2.7/runpy.py", line 174, in _run_module_as_main
#     "__main__", fname, loader, pkg_name)
#   File "/opt/localuser/anaconda2/lib/python2.7/runpy.py", line 72, in _run_code
#     exec code in run_globals
#   File "/opt/localuser/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/opt/localuser/anaconda2/lib/python2.7/site-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/opt/localuser/anaconda2/lib/python2.7/site-packages/ipykernel/kernelapp.py", line 478, in start
#     self.io_loop.start()
#   File "/opt/localuser/anaconda2/lib/python2.7/site-packages/zmq/eventloop/ioloop.py", line 177, in start
#     super(ZMQIOLoop, self).start()
#   File "/opt/localuser/anaconda2/lib/python2.7/site-packages/tornado/ioloop.py", line 832, in start
#     self._run_callback(self._callbacks.popleft())
#   File "/opt/localuser/anaconda2/lib/python2.7/site-packages/tornado/ioloop.py", line 605, in _run_callback
#     ret = callback()
#   File "/opt/localuser/anaconda2/lib/python2.7/site-packages/tornado/stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/opt/localuser/anaconda2/lib/python2.7/site-packages/ipykernel/kernelbase.py", line 263, in enter_eventloop
#     self.eventloop(self)
#   File "/opt/localuser/anaconda2/lib/python2.7/site-packages/ipykernel/eventloops.py", line 123, in loop_qt5
#     return loop_qt4(kernel)
#   File "/opt/localuser/anaconda2/lib/python2.7/site-packages/ipykernel/eventloops.py", line 111, in loop_qt4
#     _loop_qt(kernel.app)
#   File "/opt/localuser/anaconda2/lib/python2.7/site-packages/ipykernel/eventloops.py", line 95, in _loop_qt
#     app.exec_()
#   File "/opt/localuser/Work/pydev/vispy/vispy/app/backends/_qt.py", line 387, in mouseMoveEvent
#     modifiers=self._modifiers(ev),
#   File "/opt/localuser/Work/pydev/vispy/vispy/app/base.py", line 202, in _vispy_mouse_move
#     ev = self._vispy_canvas.events.mouse_move(**kwargs)
#   File "/opt/localuser/Work/pydev/vispy/vispy/util/event.py", line 455, in __call__
#     self._invoke_callback(cb, event)
#   File "/opt/localuser/Work/pydev/vispy/vispy/util/event.py", line 475, in _invoke_callback
#     self, cb_event=(cb, event))
#   << caught exception here: >>
#   File "/opt/localuser/Work/pydev/vispy/vispy/util/event.py", line 471, in _invoke_callback
#     cb(event)
#   File "/opt/localuser/Work/pydev/spiketag/spiketag/view/ctree_view.py", line 76, in on_mouse_move
#     self._select(current_cluster)
#   File "/opt/localuser/Work/pydev/spiketag/spiketag/view/ctree_view.py", line 178, in _select
#     self._clu.select(global_idx)
#   File "/opt/localuser/Work/pydev/spiketag/spiketag/base/CLU.py", line 155, in select
#     self.emit('select', action='select', caller=caller)
#   File "/opt/localuser/Work/pydev/spiketag/spiketag/utils/utils.py", line 160, in emit
#     res.append(callback(*args, **kwargs))
#   File "/opt/localuser/Work/pydev/spiketag/spiketag/view/spike_view.py", line 114, in on_select
#     self._selected = self.clu.global2local(self.clu.selectlist)
#   File "/opt/localuser/Work/pydev/spiketag/spiketag/base/CLU.py", line 78, in global2local
#     clus_nos = np.unique(self.membership[global_idx])
# IndexError: index 24901 is out of bounds for axis 1 with size 24728
# ERROR: Invoking <bound method ctree_view.on_mouse_move of <ctree_view (PyQt5) at 0x7f3ba054aad0>> for MouseEvent
# WARNING: Traceback (most recent call last):
#   File "/opt/localuser/anaconda2/lib/python2.7/runpy.py", line 174, in _run_module_as_main
#     "__main__", fname, loader, pkg_name)
#   File "/opt/localuser/anaconda2/lib/python2.7/runpy.py", line 72, in _run_code
#     exec code in run_globals
#   File "/opt/localuser/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/opt/localuser/anaconda2/lib/python2.7/site-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/opt/localuser/anaconda2/lib/python2.7/site-packages/ipykernel/kernelapp.py", line 478, in start
#     self.io_loop.start()
#   File "/opt/localuser/anaconda2/lib/python2.7/site-packages/zmq/eventloop/ioloop.py", line 177, in start
#     super(ZMQIOLoop, self).start()
#   File "/opt/localuser/anaconda2/lib/python2.7/site-packages/tornado/ioloop.py", line 832, in start
#     self._run_callback(self._callbacks.popleft())
#   File "/opt/localuser/anaconda2/lib/python2.7/site-packages/tornado/ioloop.py", line 605, in _run_callback
#     ret = callback()
#   File "/opt/localuser/anaconda2/lib/python2.7/site-packages/tornado/stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/opt/localuser/anaconda2/lib/python2.7/site-packages/ipykernel/kernelbase.py", line 263, in enter_eventloop
#     self.eventloop(self)
#   File "/opt/localuser/anaconda2/lib/python2.7/site-packages/ipykernel/eventloops.py", line 123, in loop_qt5
#     return loop_qt4(kernel)
#   File "/opt/localuser/anaconda2/lib/python2.7/site-packages/ipykernel/eventloops.py", line 111, in loop_qt4
#     _loop_qt(kernel.app)
#   File "/opt/localuser/anaconda2/lib/python2.7/site-packages/ipykernel/eventloops.py", line 95, in _loop_qt
#     app.exec_()
#   File "/opt/localuser/Work/pydev/vispy/vispy/app/backends/_qt.py", line 387, in mouseMoveEvent
#     modifiers=self._modifiers(ev),
#   File "/opt/localuser/Work/pydev/vispy/vispy/app/base.py", line 202, in _vispy_mouse_move
#     ev = self._vispy_canvas.events.mouse_move(**kwargs)
#   File "/opt/localuser/Work/pydev/vispy/vispy/util/event.py", line 455, in __call__
#     self._invoke_callback(cb, event)
#   File "/opt/localuser/Work/pydev/vispy/vispy/util/event.py", line 475, in _invoke_callback
#     self, cb_event=(cb, event))
#   << caught exception here: >>
#   File "/opt/localuser/Work/pydev/vispy/vispy/util/event.py", line 471, in _invoke_callback
#     cb(event)
#   File "/opt/localuser/Work/pydev/spiketag/spiketag/view/ctree_view.py", line 76, in on_mouse_move
#     self._select(current_cluster)
#   File "/opt/localuser/Work/pydev/spiketag/spiketag/view/ctree_view.py", line 178, in _select
#     self._clu.select(global_idx)
#   File "/opt/localuser/Work/pydev/spiketag/spiketag/base/CLU.py", line 155, in select
#     self.emit('select', action='select', caller=caller)
#   File "/opt/localuser/Work/pydev/spiketag/spiketag/utils/utils.py", line 160, in emit
#     res.append(callback(*args, **kwargs))
#   File "/opt/localuser/Work/pydev/spiketag/spiketag/view/spike_view.py", line 114, in on_select
#     self._selected = self.clu.global2local(self.clu.selectlist)
#   File "/opt/localuser/Work/pydev/spiketag/spiketag/base/CLU.py", line 78, in global2local
#     clus_nos = np.unique(self.membership[global_idx])
# IndexError: index 24901 is out of bounds for axis 1 with size 24728
# ERROR: Invoking <bound method ctree_view.on_mouse_move of <ctree_view (PyQt5) at 0x7f3ba054aad0>> for MouseEvent
# WARNING: Traceback (most recent call last):
#   File "/opt/localuser/anaconda2/lib/python2.7/runpy.py", line 174, in _run_module_as_main
#     "__main__", fname, loader, pkg_name)
#   File "/opt/localuser/anaconda2/lib/python2.7/runpy.py", line 72, in _run_code
#     exec code in run_globals
#   File "/opt/localuser/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/opt/localuser/anaconda2/lib/python2.7/site-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/opt/localuser/anaconda2/lib/python2.7/site-packages/ipykernel/kernelapp.py", line 478, in start
#     self.io_loop.start()
#   File "/opt/localuser/anaconda2/lib/python2.7/site-packages/zmq/eventloop/ioloop.py", line 177, in start
#     super(ZMQIOLoop, self).start()
#   File "/opt/localuser/anaconda2/lib/python2.7/site-packages/tornado/ioloop.py", line 832, in start
#     self._run_callback(self._callbacks.popleft())
#   File "/opt/localuser/anaconda2/lib/python2.7/site-packages/tornado/ioloop.py", line 605, in _run_callback
#     ret = callback()
#   File "/opt/localuser/anaconda2/lib/python2.7/site-packages/tornado/stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/opt/localuser/anaconda2/lib/python2.7/site-packages/ipykernel/kernelbase.py", line 263, in enter_eventloop
#     self.eventloop(self)
#   File "/opt/localuser/anaconda2/lib/python2.7/site-packages/ipykernel/eventloops.py", line 123, in loop_qt5
#     return loop_qt4(kernel)
#   File "/opt/localuser/anaconda2/lib/python2.7/site-packages/ipykernel/eventloops.py", line 111, in loop_qt4
#     _loop_qt(kernel.app)
#   File "/opt/localuser/anaconda2/lib/python2.7/site-packages/ipykernel/eventloops.py", line 95, in _loop_qt
#     app.exec_()
#   File "/opt/localuser/Work/pydev/vispy/vispy/app/backends/_qt.py", line 387, in mouseMoveEvent
#     modifiers=self._modifiers(ev),
#   File "/opt/localuser/Work/pydev/vispy/vispy/app/base.py", line 202, in _vispy_mouse_move
#     ev = self._vispy_canvas.events.mouse_move(**kwargs)
#   File "/opt/localuser/Work/pydev/vispy/vispy/util/event.py", line 455, in __call__
#     self._invoke_callback(cb, event)
#   File "/opt/localuser/Work/pydev/vispy/vispy/util/event.py", line 475, in _invoke_callback
#     self, cb_event=(cb, event))
#   << caught exception here: >>
#   File "/opt/localuser/Work/pydev/vispy/vispy/util/event.py", line 471, in _invoke_callback
#     cb(event)
#   File "/opt/localuser/Work/pydev/spiketag/spiketag/view/ctree_view.py", line 76, in on_mouse_move
#     self._select(current_cluster)
#   File "/opt/localuser/Work/pydev/spiketag/spiketag/view/ctree_view.py", line 178, in _select
#     self._clu.select(global_idx)
#   File "/opt/localuser/Work/pydev/spiketag/spiketag/base/CLU.py", line 155, in select
#     self.emit('select', action='select', caller=caller)
#   File "/opt/localuser/Work/pydev/spiketag/spiketag/utils/utils.py", line 160, in emit
#     res.append(callback(*args, **kwargs))
#   File "/opt/localuser/Work/pydev/spiketag/spiketag/view/spike_view.py", line 114, in on_select
#     self._selected = self.clu.global2local(self.clu.selectlist)
#   File "/opt/localuser/Work/pydev/spiketag/spiketag/base/CLU.py", line 78, in global2local
#     clus_nos = np.unique(self.membership[global_idx])
# IndexError: index 24901 is out of bounds for axis 1 with size 24728
# ERROR: Invoking <bound method ctree_view.on_mouse_move of <ctree_view (PyQt5) at 0x7f3ba054aad0>> for MouseEvent
# WARNING: Traceback (most recent call last):
#   File "/opt/localuser/anaconda2/lib/python2.7/runpy.py", line 174, in _run_module_as_main
#     "__main__", fname, loader, pkg_name)
#   File "/opt/localuser/anaconda2/lib/python2.7/runpy.py", line 72, in _run_code
#     exec code in run_globals
#   File "/opt/localuser/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/opt/localuser/anaconda2/lib/python2.7/site-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/opt/localuser/anaconda2/lib/python2.7/site-packages/ipykernel/kernelapp.py", line 478, in start
#     self.io_loop.start()
#   File "/opt/localuser/anaconda2/lib/python2.7/site-packages/zmq/eventloop/ioloop.py", line 177, in start
#     super(ZMQIOLoop, self).start()
#   File "/opt/localuser/anaconda2/lib/python2.7/site-packages/tornado/ioloop.py", line 832, in start
#     self._run_callback(self._callbacks.popleft())
#   File "/opt/localuser/anaconda2/lib/python2.7/site-packages/tornado/ioloop.py", line 605, in _run_callback
#     ret = callback()
#   File "/opt/localuser/anaconda2/lib/python2.7/site-packages/tornado/stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/opt/localuser/anaconda2/lib/python2.7/site-packages/ipykernel/kernelbase.py", line 263, in enter_eventloop
#     self.eventloop(self)
#   File "/opt/localuser/anaconda2/lib/python2.7/site-packages/ipykernel/eventloops.py", line 123, in loop_qt5
#     return loop_qt4(kernel)
#   File "/opt/localuser/anaconda2/lib/python2.7/site-packages/ipykernel/eventloops.py", line 111, in loop_qt4
#     _loop_qt(kernel.app)
#   File "/opt/localuser/anaconda2/lib/python2.7/site-packages/ipykernel/eventloops.py", line 95, in _loop_qt
#     app.exec_()
#   File "/opt/localuser/Work/pydev/vispy/vispy/app/backends/_qt.py", line 387, in mouseMoveEvent
#     modifiers=self._modifiers(ev),
#   File "/opt/localuser/Work/pydev/vispy/vispy/app/base.py", line 202, in _vispy_mouse_move
#     ev = self._vispy_canvas.events.mouse_move(**kwargs)
#   File "/opt/localuser/Work/pydev/vispy/vispy/util/event.py", line 455, in __call__
#     self._invoke_callback(cb, event)
#   File "/opt/localuser/Work/pydev/vispy/vispy/util/event.py", line 475, in _invoke_callback
#     self, cb_event=(cb, event))
#   << caught exception here: >>
#   File "/opt/localuser/Work/pydev/vispy/vispy/util/event.py", line 471, in _invoke_callback
#     cb(event)
#   File "/opt/localuser/Work/pydev/spiketag/spiketag/view/ctree_view.py", line 76, in on_mouse_move
#     self._select(current_cluster)
#   File "/opt/localuser/Work/pydev/spiketag/spiketag/view/ctree_view.py", line 178, in _select
#     self._clu.select(global_idx)
#   File "/opt/localuser/Work/pydev/spiketag/spiketag/base/CLU.py", line 155, in select
#     self.emit('select', action='select', caller=caller)
#   File "/opt/localuser/Work/pydev/spiketag/spiketag/utils/utils.py", line 160, in emit
#     res.append(callback(*args, **kwargs))
#   File "/opt/localuser/Work/pydev/spiketag/spiketag/view/spike_view.py", line 114, in on_select
#     self._selected = self.clu.global2local(self.clu.selectlist)
#   File "/opt/localuser/Work/pydev/spiketag/spiketag/base/CLU.py", line 78, in global2local
#     clus_nos = np.unique(self.membership[global_idx])
# IndexError: index 24901 is out of bounds for axis 1 with size 24728
# ERROR: Invoking <bound method ctree_view.on_mouse_move of <ctree_view (PyQt5) at 0x7f3ba054aad0>> for MouseEvent
# WARNING: Traceback (most recent call last):
#   File "/opt/localuser/anaconda2/lib/python2.7/runpy.py", line 174, in _run_module_as_main
#     "__main__", fname, loader, pkg_name)
#   File "/opt/localuser/anaconda2/lib/python2.7/runpy.py", line 72, in _run_code
#     exec code in run_globals
#   File "/opt/localuser/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/opt/localuser/anaconda2/lib/python2.7/site-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/opt/localuser/anaconda2/lib/python2.7/site-packages/ipykernel/kernelapp.py", line 478, in start
#     self.io_loop.start()
#   File "/opt/localuser/anaconda2/lib/python2.7/site-packages/zmq/eventloop/ioloop.py", line 177, in start
#     super(ZMQIOLoop, self).start()
#   File "/opt/localuser/anaconda2/lib/python2.7/site-packages/tornado/ioloop.py", line 832, in start
#     self._run_callback(self._callbacks.popleft())
#   File "/opt/localuser/anaconda2/lib/python2.7/site-packages/tornado/ioloop.py", line 605, in _run_callback
#     ret = callback()
#   File "/opt/localuser/anaconda2/lib/python2.7/site-packages/tornado/stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/opt/localuser/anaconda2/lib/python2.7/site-packages/ipykernel/kernelbase.py", line 263, in enter_eventloop
#     self.eventloop(self)
#   File "/opt/localuser/anaconda2/lib/python2.7/site-packages/ipykernel/eventloops.py", line 123, in loop_qt5
#     return loop_qt4(kernel)
#   File "/opt/localuser/anaconda2/lib/python2.7/site-packages/ipykernel/eventloops.py", line 111, in loop_qt4
#     _loop_qt(kernel.app)
#   File "/opt/localuser/anaconda2/lib/python2.7/site-packages/ipykernel/eventloops.py", line 95, in _loop_qt
#     app.exec_()
#   File "/opt/localuser/Work/pydev/vispy/vispy/app/backends/_qt.py", line 387, in mouseMoveEvent
#     modifiers=self._modifiers(ev),
#   File "/opt/localuser/Work/pydev/vispy/vispy/app/base.py", line 202, in _vispy_mouse_move
#     ev = self._vispy_canvas.events.mouse_move(**kwargs)
#   File "/opt/localuser/Work/pydev/vispy/vispy/util/event.py", line 455, in __call__
#     self._invoke_callback(cb, event)
#   File "/opt/localuser/Work/pydev/vispy/vispy/util/event.py", line 475, in _invoke_callback
#     self, cb_event=(cb, event))
#   << caught exception here: >>
#   File "/opt/localuser/Work/pydev/vispy/vispy/util/event.py", line 471, in _invoke_callback
#     cb(event)
#   File "/opt/localuser/Work/pydev/spiketag/spiketag/view/ctree_view.py", line 76, in on_mouse_move
#     self._select(current_cluster)
#   File "/opt/localuser/Work/pydev/spiketag/spiketag/view/ctree_view.py", line 178, in _select
#     self._clu.select(global_idx)
#   File "/opt/localuser/Work/pydev/spiketag/spiketag/base/CLU.py", line 155, in select
#     self.emit('select', action='select', caller=caller)
#   File "/opt/localuser/Work/pydev/spiketag/spiketag/utils/utils.py", line 160, in emit
#     res.append(callback(*args, **kwargs))
#   File "/opt/localuser/Work/pydev/spiketag/spiketag/view/spike_view.py", line 114, in on_select
#     self._selected = self.clu.global2local(self.clu.selectlist)
#   File "/opt/localuser/Work/pydev/spiketag/spiketag/base/CLU.py", line 78, in global2local
#     clus_nos = np.unique(self.membership[global_idx])
# IndexError: index 24901 is out of bounds for axis 1 with size 24728
# ERROR: Invoking <bound method ctree_view.on_mouse_move of <ctree_view (PyQt5) at 0x7f3ba054aad0>> for MouseEvent
# WARNING: Traceback (most recent call last):
#   File "/opt/localuser/anaconda2/lib/python2.7/runpy.py", line 174, in _run_module_as_main
#     "__main__", fname, loader, pkg_name)
#   File "/opt/localuser/anaconda2/lib/python2.7/runpy.py", line 72, in _run_code
#     exec code in run_globals
#   File "/opt/localuser/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/opt/localuser/anaconda2/lib/python2.7/site-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/opt/localuser/anaconda2/lib/python2.7/site-packages/ipykernel/kernelapp.py", line 478, in start
#     self.io_loop.start()
#   File "/opt/localuser/anaconda2/lib/python2.7/site-packages/zmq/eventloop/ioloop.py", line 177, in start
#     super(ZMQIOLoop, self).start()
#   File "/opt/localuser/anaconda2/lib/python2.7/site-packages/tornado/ioloop.py", line 832, in start
#     self._run_callback(self._callbacks.popleft())
#   File "/opt/localuser/anaconda2/lib/python2.7/site-packages/tornado/ioloop.py", line 605, in _run_callback
#     ret = callback()
#   File "/opt/localuser/anaconda2/lib/python2.7/site-packages/tornado/stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/opt/localuser/anaconda2/lib/python2.7/site-packages/ipykernel/kernelbase.py", line 263, in enter_eventloop
#     self.eventloop(self)
#   File "/opt/localuser/anaconda2/lib/python2.7/site-packages/ipykernel/eventloops.py", line 123, in loop_qt5
#     return loop_qt4(kernel)
#   File "/opt/localuser/anaconda2/lib/python2.7/site-packages/ipykernel/eventloops.py", line 111, in loop_qt4
#     _loop_qt(kernel.app)
#   File "/opt/localuser/anaconda2/lib/python2.7/site-packages/ipykernel/eventloops.py", line 95, in _loop_qt
#     app.exec_()
#   File "/opt/localuser/Work/pydev/vispy/vispy/app/backends/_qt.py", line 387, in mouseMoveEvent
#     modifiers=self._modifiers(ev),
#   File "/opt/localuser/Work/pydev/vispy/vispy/app/base.py", line 202, in _vispy_mouse_move
#     ev = self._vispy_canvas.events.mouse_move(**kwargs)
#   File "/opt/localuser/Work/pydev/vispy/vispy/util/event.py", line 455, in __call__
#     self._invoke_callback(cb, event)
#   File "/opt/localuser/Work/pydev/vispy/vispy/util/event.py", line 475, in _invoke_callback
#     self, cb_event=(cb, event))
#   << caught exception here: >>
#   File "/opt/localuser/Work/pydev/vispy/vispy/util/event.py", line 471, in _invoke_callback
#     cb(event)
#   File "/opt/localuser/Work/pydev/spiketag/spiketag/view/ctree_view.py", line 76, in on_mouse_move
#     self._select(current_cluster)
#   File "/opt/localuser/Work/pydev/spiketag/spiketag/view/ctree_view.py", line 178, in _select
#     self._clu.select(global_idx)
#   File "/opt/localuser/Work/pydev/spiketag/spiketag/base/CLU.py", line 155, in select
#     self.emit('select', action='select', caller=caller)
#   File "/opt/localuser/Work/pydev/spiketag/spiketag/utils/utils.py", line 160, in emit
#     res.append(callback(*args, **kwargs))
#   File "/opt/localuser/Work/pydev/spiketag/spiketag/view/spike_view.py", line 114, in on_select
#     self._selected = self.clu.global2local(self.clu.selectlist)
#   File "/opt/localuser/Work/pydev/spiketag/spiketag/base/CLU.py", line 78, in global2local
#     clus_nos = np.unique(self.membership[global_idx])
# IndexError: index 24901 is out of bounds for axis 1 with size 24728
# ERROR: Invoking <bound method ctree_view.on_mouse_move of <ctree_view (PyQt5) at 0x7f3ba054aad0>> for MouseEvent
# WARNING: Traceback (most recent call last):
#   File "/opt/localuser/anaconda2/lib/python2.7/runpy.py", line 174, in _run_module_as_main
#     "__main__", fname, loader, pkg_name)
#   File "/opt/localuser/anaconda2/lib/python2.7/runpy.py", line 72, in _run_code
#     exec code in run_globals
#   File "/opt/localuser/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/opt/localuser/anaconda2/lib/python2.7/site-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/opt/localuser/anaconda2/lib/python2.7/site-packages/ipykernel/kernelapp.py", line 478, in start
#     self.io_loop.start()
#   File "/opt/localuser/anaconda2/lib/python2.7/site-packages/zmq/eventloop/ioloop.py", line 177, in start
#     super(ZMQIOLoop, self).start()
#   File "/opt/localuser/anaconda2/lib/python2.7/site-packages/tornado/ioloop.py", line 832, in start
#     self._run_callback(self._callbacks.popleft())
#   File "/opt/localuser/anaconda2/lib/python2.7/site-packages/tornado/ioloop.py", line 605, in _run_callback
#     ret = callback()
#   File "/opt/localuser/anaconda2/lib/python2.7/site-packages/tornado/stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/opt/localuser/anaconda2/lib/python2.7/site-packages/ipykernel/kernelbase.py", line 263, in enter_eventloop
#     self.eventloop(self)
#   File "/opt/localuser/anaconda2/lib/python2.7/site-packages/ipykernel/eventloops.py", line 123, in loop_qt5
#     return loop_qt4(kernel)
#   File "/opt/localuser/anaconda2/lib/python2.7/site-packages/ipykernel/eventloops.py", line 111, in loop_qt4
#     _loop_qt(kernel.app)
#   File "/opt/localuser/anaconda2/lib/python2.7/site-packages/ipykernel/eventloops.py", line 95, in _loop_qt
#     app.exec_()
#   File "/opt/localuser/Work/pydev/vispy/vispy/app/backends/_qt.py", line 387, in mouseMoveEvent
#     modifiers=self._modifiers(ev),
#   File "/opt/localuser/Work/pydev/vispy/vispy/app/base.py", line 202, in _vispy_mouse_move
#     ev = self._vispy_canvas.events.mouse_move(**kwargs)
#   File "/opt/localuser/Work/pydev/vispy/vispy/util/event.py", line 455, in __call__
#     self._invoke_callback(cb, event)
#   File "/opt/localuser/Work/pydev/vispy/vispy/util/event.py", line 475, in _invoke_callback
#     self, cb_event=(cb, event))
#   << caught exception here: >>
#   File "/opt/localuser/Work/pydev/vispy/vispy/util/event.py", line 471, in _invoke_callback
#     cb(event)
#   File "/opt/localuser/Work/pydev/spiketag/spiketag/view/ctree_view.py", line 76, in on_mouse_move
#     self._select(current_cluster)
#   File "/opt/localuser/Work/pydev/spiketag/spiketag/view/ctree_view.py", line 178, in _select
#     self._clu.select(global_idx)
#   File "/opt/localuser/Work/pydev/spiketag/spiketag/base/CLU.py", line 155, in select
#     self.emit('select', action='select', caller=caller)
# ...
#     self.eventloop(self)
#   File "/opt/localuser/anaconda2/lib/python2.7/site-packages/ipykernel/eventloops.py", line 123, in loop_qt5
#     return loop_qt4(kernel)
#   File "/opt/localuser/anaconda2/lib/python2.7/site-packages/ipykernel/eventloops.py", line 111, in loop_qt4
#     _loop_qt(kernel.app)
#   File "/opt/localuser/anaconda2/lib/python2.7/site-packages/ipykernel/eventloops.py", line 95, in _loop_qt
#     app.exec_()
#   File "/opt/localuser/Work/pydev/vispy/vispy/app/backends/_qt.py", line 387, in mouseMoveEvent
#     modifiers=self._modifiers(ev),
#   File "/opt/localuser/Work/pydev/vispy/vispy/app/base.py", line 202, in _vispy_mouse_move
#     ev = self._vispy_canvas.events.mouse_move(**kwargs)
#   File "/opt/localuser/Work/pydev/vispy/vispy/util/event.py", line 455, in __call__
#     self._invoke_callback(cb, event)
#   File "/opt/localuser/Work/pydev/vispy/vispy/util/event.py", line 475, in _invoke_callback
#     self, cb_event=(cb, event))
#   << caught exception here: >>
#   File "/opt/localuser/Work/pydev/vispy/vispy/util/event.py", line 471, in _invoke_callback
#     cb(event)
#   File "/opt/localuser/Work/pydev/spiketag/spiketag/view/ctree_view.py", line 76, in on_mouse_move
#     self._select(current_cluster)
#   File "/opt/localuser/Work/pydev/spiketag/spiketag/view/ctree_view.py", line 178, in _select
#     self._clu.select(global_idx)
#   File "/opt/localuser/Work/pydev/spiketag/spiketag/base/CLU.py", line 155, in select
#     self.emit('select', action='select', caller=caller)
#   File "/opt/localuser/Work/pydev/spiketag/spiketag/utils/utils.py", line 160, in emit
#     res.append(callback(*args, **kwargs))
#   File "/opt/localuser/Work/pydev/spiketag/spiketag/view/spike_view.py", line 114, in on_select
#     self._selected = self.clu.global2local(self.clu.selectlist)
#   File "/opt/localuser/Work/pydev/spiketag/spiketag/base/CLU.py", line 78, in global2local
#     clus_nos = np.unique(self.membership[global_idx])
# IndexError: index 24871 is out of bounds for axis 1 with size 24728
# ERROR: Invoking <bound method ctree_view.on_mouse_move of <ctree_view (PyQt5) at 0x7f3ba054aad0>> for MouseEvent
# WARNING: Traceback (most recent call last):
#   File "/opt/localuser/anaconda2/lib/python2.7/runpy.py", line 174, in _run_module_as_main
#     "__main__", fname, loader, pkg_name)
#   File "/opt/localuser/anaconda2/lib/python2.7/runpy.py", line 72, in _run_code
#     exec code in run_globals
#   File "/opt/localuser/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/opt/localuser/anaconda2/lib/python2.7/site-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/opt/localuser/anaconda2/lib/python2.7/site-packages/ipykernel/kernelapp.py", line 478, in start
#     self.io_loop.start()
#   File "/opt/localuser/anaconda2/lib/python2.7/site-packages/zmq/eventloop/ioloop.py", line 177, in start
#     super(ZMQIOLoop, self).start()
#   File "/opt/localuser/anaconda2/lib/python2.7/site-packages/tornado/ioloop.py", line 832, in start
#     self._run_callback(self._callbacks.popleft())
#   File "/opt/localuser/anaconda2/lib/python2.7/site-packages/tornado/ioloop.py", line 605, in _run_callback
#     ret = callback()
#   File "/opt/localuser/anaconda2/lib/python2.7/site-packages/tornado/stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/opt/localuser/anaconda2/lib/python2.7/site-packages/ipykernel/kernelbase.py", line 263, in enter_eventloop
#     self.eventloop(self)
#   File "/opt/localuser/anaconda2/lib/python2.7/site-packages/ipykernel/eventloops.py", line 123, in loop_qt5
#     return loop_qt4(kernel)
#   File "/opt/localuser/anaconda2/lib/python2.7/site-packages/ipykernel/eventloops.py", line 111, in loop_qt4
#     _loop_qt(kernel.app)
#   File "/opt/localuser/anaconda2/lib/python2.7/site-packages/ipykernel/eventloops.py", line 95, in _loop_qt
#     app.exec_()
#   File "/opt/localuser/Work/pydev/vispy/vispy/app/backends/_qt.py", line 387, in mouseMoveEvent
#     modifiers=self._modifiers(ev),
#   File "/opt/localuser/Work/pydev/vispy/vispy/app/base.py", line 202, in _vispy_mouse_move
#     ev = self._vispy_canvas.events.mouse_move(**kwargs)
#   File "/opt/localuser/Work/pydev/vispy/vispy/util/event.py", line 455, in __call__
#     self._invoke_callback(cb, event)
#   File "/opt/localuser/Work/pydev/vispy/vispy/util/event.py", line 475, in _invoke_callback
#     self, cb_event=(cb, event))
#   << caught exception here: >>
#   File "/opt/localuser/Work/pydev/vispy/vispy/util/event.py", line 471, in _invoke_callback
#     cb(event)
#   File "/opt/localuser/Work/pydev/spiketag/spiketag/view/ctree_view.py", line 76, in on_mouse_move
#     self._select(current_cluster)
#   File "/opt/localuser/Work/pydev/spiketag/spiketag/view/ctree_view.py", line 178, in _select
#     self._clu.select(global_idx)
#   File "/opt/localuser/Work/pydev/spiketag/spiketag/base/CLU.py", line 155, in select
#     self.emit('select', action='select', caller=caller)
#   File "/opt/localuser/Work/pydev/spiketag/spiketag/utils/utils.py", line 160, in emit
#     res.append(callback(*args, **kwargs))
#   File "/opt/localuser/Work/pydev/spiketag/spiketag/view/spike_view.py", line 114, in on_select
#     self._selected = self.clu.global2local(self.clu.selectlist)
#   File "/opt/localuser/Work/pydev/spiketag/spiketag/base/CLU.py", line 78, in global2local
#     clus_nos = np.unique(self.membership[global_idx])
# IndexError: index 24871 is out of bounds for axis 1 with size 24728
# ERROR: Invoking <bound method ctree_view.on_mouse_move of <ctree_view (PyQt5) at 0x7f3ba054aad0>> for MouseEvent
# WARNING: Traceback (most recent call last):
#   File "/opt/localuser/anaconda2/lib/python2.7/runpy.py", line 174, in _run_module_as_main
#     "__main__", fname, loader, pkg_name)
#   File "/opt/localuser/anaconda2/lib/python2.7/runpy.py", line 72, in _run_code
#     exec code in run_globals
#   File "/opt/localuser/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/opt/localuser/anaconda2/lib/python2.7/site-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/opt/localuser/anaconda2/lib/python2.7/site-packages/ipykernel/kernelapp.py", line 478, in start
#     self.io_loop.start()
#   File "/opt/localuser/anaconda2/lib/python2.7/site-packages/zmq/eventloop/ioloop.py", line 177, in start
#     super(ZMQIOLoop, self).start()
#   File "/opt/localuser/anaconda2/lib/python2.7/site-packages/tornado/ioloop.py", line 832, in start
#     self._run_callback(self._callbacks.popleft())
#   File "/opt/localuser/anaconda2/lib/python2.7/site-packages/tornado/ioloop.py", line 605, in _run_callback
#     ret = callback()
#   File "/opt/localuser/anaconda2/lib/python2.7/site-packages/tornado/stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/opt/localuser/anaconda2/lib/python2.7/site-packages/ipykernel/kernelbase.py", line 263, in enter_eventloop
#     self.eventloop(self)
#   File "/opt/localuser/anaconda2/lib/python2.7/site-packages/ipykernel/eventloops.py", line 123, in loop_qt5
#     return loop_qt4(kernel)
#   File "/opt/localuser/anaconda2/lib/python2.7/site-packages/ipykernel/eventloops.py", line 111, in loop_qt4
#     _loop_qt(kernel.app)
#   File "/opt/localuser/anaconda2/lib/python2.7/site-packages/ipykernel/eventloops.py", line 95, in _loop_qt
#     app.exec_()
#   File "/opt/localuser/Work/pydev/vispy/vispy/app/backends/_qt.py", line 387, in mouseMoveEvent
#     modifiers=self._modifiers(ev),
#   File "/opt/localuser/Work/pydev/vispy/vispy/app/base.py", line 202, in _vispy_mouse_move
#     ev = self._vispy_canvas.events.mouse_move(**kwargs)
#   File "/opt/localuser/Work/pydev/vispy/vispy/util/event.py", line 455, in __call__
#     self._invoke_callback(cb, event)
#   File "/opt/localuser/Work/pydev/vispy/vispy/util/event.py", line 475, in _invoke_callback
#     self, cb_event=(cb, event))
#   << caught exception here: >>
#   File "/opt/localuser/Work/pydev/vispy/vispy/util/event.py", line 471, in _invoke_callback
#     cb(event)
#   File "/opt/localuser/Work/pydev/spiketag/spiketag/view/ctree_view.py", line 76, in on_mouse_move
#     self._select(current_cluster)
#   File "/opt/localuser/Work/pydev/spiketag/spiketag/view/ctree_view.py", line 178, in _select
#     self._clu.select(global_idx)
#   File "/opt/localuser/Work/pydev/spiketag/spiketag/base/CLU.py", line 155, in select
#     self.emit('select', action='select', caller=caller)
#   File "/opt/localuser/Work/pydev/spiketag/spiketag/utils/utils.py", line 160, in emit
#     res.append(callback(*args, **kwargs))
#   File "/opt/localuser/Work/pydev/spiketag/spiketag/view/spike_view.py", line 114, in on_select
#     self._selected = self.clu.global2local(self.clu.selectlist)
#   File "/opt/localuser/Work/pydev/spiketag/spiketag/base/CLU.py", line 78, in global2local
#     clus_nos = np.unique(self.membership[global_idx])
# IndexError: index 24871 is out of bounds for axis 1 with size 24728
# ERROR: Invoking <bound method ctree_view.on_mouse_move of <ctree_view (PyQt5) at 0x7f3ba054aad0>> for MouseEvent
# WARNING: Traceback (most recent call last):
#   File "/opt/localuser/anaconda2/lib/python2.7/runpy.py", line 174, in _run_module_as_main
#     "__main__", fname, loader, pkg_name)
#   File "/opt/localuser/anaconda2/lib/python2.7/runpy.py", line 72, in _run_code
#     exec code in run_globals
#   File "/opt/localuser/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/opt/localuser/anaconda2/lib/python2.7/site-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/opt/localuser/anaconda2/lib/python2.7/site-packages/ipykernel/kernelapp.py", line 478, in start
#     self.io_loop.start()
#   File "/opt/localuser/anaconda2/lib/python2.7/site-packages/zmq/eventloop/ioloop.py", line 177, in start
#     super(ZMQIOLoop, self).start()
#   File "/opt/localuser/anaconda2/lib/python2.7/site-packages/tornado/ioloop.py", line 832, in start
#     self._run_callback(self._callbacks.popleft())
#   File "/opt/localuser/anaconda2/lib/python2.7/site-packages/tornado/ioloop.py", line 605, in _run_callback
#     ret = callback()
#   File "/opt/localuser/anaconda2/lib/python2.7/site-packages/tornado/stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/opt/localuser/anaconda2/lib/python2.7/site-packages/ipykernel/kernelbase.py", line 263, in enter_eventloop
#     self.eventloop(self)
#   File "/opt/localuser/anaconda2/lib/python2.7/site-packages/ipykernel/eventloops.py", line 123, in loop_qt5
#     return loop_qt4(kernel)
#   File "/opt/localuser/anaconda2/lib/python2.7/site-packages/ipykernel/eventloops.py", line 111, in loop_qt4
#     _loop_qt(kernel.app)
#   File "/opt/localuser/anaconda2/lib/python2.7/site-packages/ipykernel/eventloops.py", line 95, in _loop_qt
#     app.exec_()
#   File "/opt/localuser/Work/pydev/vispy/vispy/app/backends/_qt.py", line 387, in mouseMoveEvent
#     modifiers=self._modifiers(ev),
#   File "/opt/localuser/Work/pydev/vispy/vispy/app/base.py", line 202, in _vispy_mouse_move
#     ev = self._vispy_canvas.events.mouse_move(**kwargs)
#   File "/opt/localuser/Work/pydev/vispy/vispy/util/event.py", line 455, in __call__
#     self._invoke_callback(cb, event)
#   File "/opt/localuser/Work/pydev/vispy/vispy/util/event.py", line 475, in _invoke_callback
#     self, cb_event=(cb, event))
#   << caught exception here: >>
#   File "/opt/localuser/Work/pydev/vispy/vispy/util/event.py", line 471, in _invoke_callback
#     cb(event)
#   File "/opt/localuser/Work/pydev/spiketag/spiketag/view/ctree_view.py", line 76, in on_mouse_move
#     self._select(current_cluster)
#   File "/opt/localuser/Work/pydev/spiketag/spiketag/view/ctree_view.py", line 178, in _select
#     self._clu.select(global_idx)
#   File "/opt/localuser/Work/pydev/spiketag/spiketag/base/CLU.py", line 155, in select
#     self.emit('select', action='select', caller=caller)
#   File "/opt/localuser/Work/pydev/spiketag/spiketag/utils/utils.py", line 160, in emit
#     res.append(callback(*args, **kwargs))
#   File "/opt/localuser/Work/pydev/spiketag/spiketag/view/spike_view.py", line 114, in on_select
#     self._selected = self.clu.global2local(self.clu.selectlist)
#   File "/opt/localuser/Work/pydev/spiketag/spiketag/base/CLU.py", line 78, in global2local
#     clus_nos = np.unique(self.membership[global_idx])
# IndexError: index 24871 is out of bounds for axis 1 with size 24728
# ERROR: Invoking <bound method ctree_view.on_mouse_move of <ctree_view (PyQt5) at 0x7f3ba054aad0>> for MouseEvent
# WARNING: Traceback (most recent call last):
#   File "/opt/localuser/anaconda2/lib/python2.7/runpy.py", line 174, in _run_module_as_main
#     "__main__", fname, loader, pkg_name)
#   File "/opt/localuser/anaconda2/lib/python2.7/runpy.py", line 72, in _run_code
#     exec code in run_globals
#   File "/opt/localuser/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/opt/localuser/anaconda2/lib/python2.7/site-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/opt/localuser/anaconda2/lib/python2.7/site-packages/ipykernel/kernelapp.py", line 478, in start
#     self.io_loop.start()
#   File "/opt/localuser/anaconda2/lib/python2.7/site-packages/zmq/eventloop/ioloop.py", line 177, in start
#     super(ZMQIOLoop, self).start()
#   File "/opt/localuser/anaconda2/lib/python2.7/site-packages/tornado/ioloop.py", line 832, in start
#     self._run_callback(self._callbacks.popleft())
#   File "/opt/localuser/anaconda2/lib/python2.7/site-packages/tornado/ioloop.py", line 605, in _run_callback
#     ret = callback()
#   File "/opt/localuser/anaconda2/lib/python2.7/site-packages/tornado/stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/opt/localuser/anaconda2/lib/python2.7/site-packages/ipykernel/kernelbase.py", line 263, in enter_eventloop
#     self.eventloop(self)
#   File "/opt/localuser/anaconda2/lib/python2.7/site-packages/ipykernel/eventloops.py", line 123, in loop_qt5
#     return loop_qt4(kernel)
#   File "/opt/localuser/anaconda2/lib/python2.7/site-packages/ipykernel/eventloops.py", line 111, in loop_qt4
#     _loop_qt(kernel.app)
#   File "/opt/localuser/anaconda2/lib/python2.7/site-packages/ipykernel/eventloops.py", line 95, in _loop_qt
#     app.exec_()
#   File "/opt/localuser/Work/pydev/vispy/vispy/app/backends/_qt.py", line 387, in mouseMoveEvent
#     modifiers=self._modifiers(ev),
#   File "/opt/localuser/Work/pydev/vispy/vispy/app/base.py", line 202, in _vispy_mouse_move
#     ev = self._vispy_canvas.events.mouse_move(**kwargs)
#   File "/opt/localuser/Work/pydev/vispy/vispy/util/event.py", line 455, in __call__
#     self._invoke_callback(cb, event)
#   File "/opt/localuser/Work/pydev/vispy/vispy/util/event.py", line 475, in _invoke_callback
#     self, cb_event=(cb, event))
#   << caught exception here: >>
#   File "/opt/localuser/Work/pydev/vispy/vispy/util/event.py", line 471, in _invoke_callback
#     cb(event)
#   File "/opt/localuser/Work/pydev/spiketag/spiketag/view/ctree_view.py", line 76, in on_mouse_move
#     self._select(current_cluster)
#   File "/opt/localuser/Work/pydev/spiketag/spiketag/view/ctree_view.py", line 178, in _select
#     self._clu.select(global_idx)
#   File "/opt/localuser/Work/pydev/spiketag/spiketag/base/CLU.py", line 155, in select
#     self.emit('select', action='select', caller=caller)
#   File "/opt/localuser/Work/pydev/spiketag/spiketag/utils/utils.py", line 160, in emit
#     res.append(callback(*args, **kwargs))
#   File "/opt/localuser/Work/pydev/spiketag/spiketag/view/spike_view.py", line 114, in on_select
#     self._selected = self.clu.global2local(self.clu.selectlist)
#   File "/opt/localuser/Work/pydev/spiketag/spiketag/base/CLU.py", line 78, in global2local
#     clus_nos = np.unique(self.membership[global_idx])
# IndexError: index 24871 is out of bounds for axis 1 with size 24728
# ERROR: Invoking <bound method ctree_view.on_mouse_move of <ctree_view (PyQt5) at 0x7f3ba054aad0>> for MouseEvent

# %% [markdown]
# ## spike time

# %%
spk_time = ctrl.model.gtimes

# %%
clu = ctrl.model.clu[0]

# %%
clu.index[1]
# Out:
# array([   4,  194,  206,  300,  717,  765,  791,  819,  837,  844,  884,
#         963,  974, 1000, 1131, 1195, 1207, 1285, 1318, 1329, 1343, 1386,
#        1485, 1488, 1490, 1508, 1531, 1779, 1891, 1953, 2353, 2540, 2615,
